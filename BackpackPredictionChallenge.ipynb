# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarMantri/deeplearning/blob/SagarMantri-deeplearning-develop/BackpackPredictionChallenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/train.csv')

# %%
df.head()
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
# 3   3          Nike    Nylon   Small           8.0                Yes
# 4   4        Adidas   Canvas  Medium           1.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0         No       Tote  Black             11.611723  112.15875
# 1        Yes  Messenger  Green             27.078537   68.88056
# 2         No  Messenger    Red             16.643760   39.17320
# 3         No  Messenger  Green             12.937220   80.60793
# 4        Yes  Messenger  Green             17.749338   86.02312

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    300000 non-null  int64
#  1   Brand                 290295 non-null  object
#  2   Material              291653 non-null  object
#  3   Size                  293405 non-null  object
#  4   Compartments          300000 non-null  float64
#  5   Laptop Compartment    292556 non-null  object
#  6   Waterproof            292950 non-null  object
#  7   Style                 292030 non-null  object
#  8   Color                 290050 non-null  object
#  9   Weight Capacity (kg)  299862 non-null  float64
#  10  Price                 300000 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 25.2+ MB

# %%
df.shape
# Out:
# (300000, 11)

# %%
df.isnull().sum()
# Out:
# id                         0
# Brand                   9705
# Material                8347
# Size                    6595
# Compartments               0
# Laptop Compartment      7444
# Waterproof              7050
# Style                   7970
# Color                   9950
# Weight Capacity (kg)     138
# Price                      0
# dtype: int64

# %%
df['Color'].value_counts()
# Out:
# Color
# Pink     51690
# Gray     50280
# Blue     48097
# Red      47219
# Green    46386
# Black    46378
# Name: count, dtype: int64

# %%
df['Waterproof'].value_counts()
# Out:
# Waterproof
# Yes    148077
# No     144873
# Name: count, dtype: int64

# %%
df['Laptop Compartment'].value_counts()
# Out:
# Laptop Compartment
# Yes    148342
# No     144214
# Name: count, dtype: int64

# %%
df['Style'].value_counts()
# Out:
# Style
# Messenger    100031
# Tote          97438
# Backpack      94561
# Name: count, dtype: int64

# %%
df['Material'].value_counts()
# Out:
# Material
# Polyester    79630
# Leather      73416
# Nylon        70603
# Canvas       68004
# Name: count, dtype: int64

# %%
y=df['Price']
x=df.iloc[:,:-1]

# %%
x=x.drop(columns=['id'])

# %%
x
# Out:
#                Brand Material    Size  Compartments Laptop Compartment  \
# 0           Jansport  Leather  Medium           7.0                Yes
# 1           Jansport   Canvas   Small          10.0                Yes
# 2       Under Armour  Leather   Small           2.0                Yes
# 3               Nike    Nylon   Small           8.0                Yes
# 4             Adidas   Canvas  Medium           1.0                Yes
# ...              ...      ...     ...           ...                ...
# 299995        Adidas  Leather   Small           9.0                 No
# 299996      Jansport  Leather   Large           6.0                 No
# 299997          Puma   Canvas   Large           9.0                Yes
# 299998        Adidas    Nylon   Small           1.0                 No
# 299999  Under Armour   Canvas   Small           2.0                 No
#
#        Waterproof      Style  Color  Weight Capacity (kg)
# ...

# %% [markdown]
# Handling missing values

# %%
#Handling Missing values

def handle_missing_value(df):
  for col in df.columns:
    if df[col].dtype=='object':
      df[col].fillna(df[col].mode()[0], inplace=True)
    else:
      df[col].fillna(df[col].median(), inplace=True)
  return df

# %%
x.isnull().sum()
# Out:
# Brand                   9705
# Material                8347
# Size                    6595
# Compartments               0
# Laptop Compartment      7444
# Waterproof              7050
# Style                   7970
# Color                   9950
# Weight Capacity (kg)     138
# dtype: int64

# %%
x=handle_missing_value(x)
# Out:
# <ipython-input-29-1b2ad36324ac>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# <ipython-input-29-1b2ad36324ac>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
x.isnull().sum()
# Out:
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# dtype: int64
